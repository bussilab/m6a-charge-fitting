# %%
import numpy as np
import pandas as pd

data=[]
data.append(np.loadtxt('Aduri_charges.txt'))
data.append(np.loadtxt('Fit_A_inc.txt'))
data.append(np.loadtxt('fit_A_charges.txt'))
data.append(np.loadtxt('Fit_AB_charges.txt'))
data.append(np.loadtxt('Gaussian_Resp_anti.txt'))
data.append(np.loadtxt('Gaussian_Resp_syn.txt'))
data.append(np.loadtxt('Krepl.txt'))

data=np.array(data)
charges=pd.DataFrame(np.transpose(data), index=['N9','C8','H8','N7','C5','C6','N6','H61','C10','H101','H102','H103','N1','C2','H2','N3','C4'], 
                     columns=['Aduri', 'fit_A_inc','fit_A', 'fit_AB', 'RESP_anti', 'RESP_syn', 'Krepl'])
charges
# Out:
#         Aduri  fit_A_inc     fit_A    fit_AB  RESP_anti  RESP_syn   Krepl
# N9   -0.07829  -0.078290 -0.078290 -0.078290    -0.0564   -0.1834 -0.1719
# C8    0.13844   0.138440  0.138440  0.138440     0.0815    0.2573  0.0631
# H8    0.16681   0.166810  0.166810  0.166810     0.1726    0.1329  0.1973
# N7   -0.59080  -0.590800 -0.590800 -0.590800    -0.5250   -0.5854 -0.5652
# C5    0.03544   0.035440  0.035440  0.035440     0.0226   -0.2346  0.0152
# C6    0.44911   0.513112  0.468512  0.458112     0.5880    0.7140  0.5597
# N6   -0.30623  -0.268228 -0.228928 -0.257228    -0.3756   -0.4189 -0.4756
# H61   0.28948   0.359482  0.388882  0.356482     0.3306    0.3392  0.3232
# C10  -0.28897  -0.293970 -0.284670 -0.255970    -0.3009   -0.3239 -0.0774
# H101  0.12596   0.083960  0.075360  0.090960     0.1299    0.1400  0.0774
# H102  0.12596   0.083960  0.075360  0.090960     0.1299    0.1400  0.0774
# H103  0.12596   0.083960  0.075360  0.090960     0.1299    0.1400  0.0774
# ...

# %%
charges.to_csv('table_charges.csv')
